# %%
# データのヘッダー

# %%
# -- kaggle amex - train 集約表作成SQL 
-- categorical:['B_30', 'B_38', 'D_114', 'D_116', 'D_117', 'D_120', 'D_126', 'D_63', 'D_64', 'D_66', 'D_68

SELECT

customer_ID
,count(S_2) as count
,min(S_2) as S_2_min,max(S_2) as S_2_max,date_diff(max(S_2), min(S_2), DAY) as S_2_days
,min(P_2) as P_2_min,max(P_2) as P_2_max
,min(D_39) as D_39_min,max(D_39) as D_39_max
,min(B_1) as B_1_min,max(B_1) as B_1_max
,min(B_2) as B_2_min,max(B_2) as B_2_max
,min(R_1) as R_1_min,max(R_1) as R_1_max
,min(S_3) as S_3_min,max(S_3) as S_3_max
,min(D_41) as D_41_min,max(D_41) as D_41_max
,min(B_3) as B_3_min,max(B_3) as B_3_max
,min(D_42) as D_42_min,max(D_42) as D_42_max
,min(D_43) as D_43_min,max(D_43) as D_43_max
,min(D_44) as D_44_min,max(D_44) as D_44_max
,min(B_4) as B_4_min,max(B_4) as B_4_max
,min(D_45) as D_45_min,max(D_45) as D_45_max
,min(B_5) as B_5_min,max(B_5) as B_5_max
,min(R_2) as R_2_min,max(R_2) as R_2_max
,min(D_46) as D_46_min,max(D_46) as D_46_max
,min(D_47) as D_47_min,max(D_47) as D_47_max
,min(D_48) as D_48_min,max(D_48) as D_48_max
,min(D_49) as D_49_min,max(D_49) as D_49_max
,min(B_6) as B_6_min,max(B_6) as B_6_max
,min(B_7) as B_7_min,max(B_7) as B_7_max
,min(B_8) as B_8_min,max(B_8) as B_8_max
,min(D_50) as D_50_min,max(D_50) as D_50_max
,min(D_51) as D_51_min,max(D_51) as D_51_max
,min(B_9) as B_9_min,max(B_9) as B_9_max
,min(R_3) as R_3_min,max(R_3) as R_3_max
,min(D_52) as D_52_min,max(D_52) as D_52_max
,min(P_3) as P_3_min,max(P_3) as P_3_max
,min(B_10) as B_10_min,max(B_10) as B_10_max
,min(D_53) as D_53_min,max(D_53) as D_53_max
,min(S_5) as S_5_min,max(S_5) as S_5_max
,min(B_11) as B_11_min,max(B_11) as B_11_max
,min(S_6) as S_6_min,max(S_6) as S_6_max
,min(D_54) as D_54_min,max(D_54) as D_54_max
,min(R_4) as R_4_min,max(R_4) as R_4_max
,min(S_7) as S_7_min,max(S_7) as S_7_max
,min(B_12) as B_12_min,max(B_12) as B_12_max
,min(S_8) as S_8_min,max(S_8) as S_8_max
,min(D_55) as D_55_min,max(D_55) as D_55_max
,min(D_56) as D_56_min,max(D_56) as D_56_max
,min(B_13) as B_13_min,max(B_13) as B_13_max
,min(R_5) as R_5_min,max(R_5) as R_5_max
,min(D_58) as D_58_min,max(D_58) as D_58_max
,min(S_9) as S_9_min,max(S_9) as S_9_max
,min(B_14) as B_14_min,max(B_14) as B_14_max
,min(D_59) as D_59_min,max(D_59) as D_59_max
,min(D_60) as D_60_min,max(D_60) as D_60_max
,min(D_61) as D_61_min,max(D_61) as D_61_max
,min(B_15) as B_15_min,max(B_15) as B_15_max
,min(S_11) as S_11_min,max(S_11) as S_11_max
,min(D_62) as D_62_min,max(D_62) as D_62_max
,count(if(D_63 is null, D_63, null)) as D_63_cnt_null
,count(if(D_63 = 'CL', D_63, null)) as D_63_cnt_CL
,count(if(D_63 = 'CO', D_63, null)) as D_63_cnt_CO
,count(if(D_63 = 'CR', D_63, null)) as D_63_cnt_CR
,count(if(D_63 = 'XL', D_63, null)) as D_63_cnt_XL
,count(if(D_63 = 'XM', D_63, null)) as D_63_cnt_XM
,count(if(D_63 = 'XZ', D_63, null)) as D_63_cnt_XZ
,count(if(D_64 is null, D_64, null)) as D_64_cnt_null
,count(if(D_64 = '-1', D_64, null)) as D_64_cnt_m1
,count(if(D_64 = 'O', D_64, null)) as D_64_cnt_O
,count(if(D_64 = 'R', D_64, null)) as D_64_cnt_R
,count(if(D_64 = 'U', D_64, null)) as D_64_cnt_U
,min(D_65) as D_65_min,max(D_65) as D_65_max
,min(B_16) as B_16_min,max(B_16) as B_16_max
,min(B_17) as B_17_min,max(B_17) as B_17_max
,min(B_18) as B_18_min,max(B_18) as B_18_max
,min(B_19) as B_19_min,max(B_19) as B_19_max
,count(if(D_66 is null, D_66, null)) as D_66_cnt_null
,count(if(D_66 = 0, D_66, null)) as D_66_cnt_0
,count(if(D_66 = 1, D_66, null)) as D_66_cnt_1
,min(B_20) as B_20_min,max(B_20) as B_20_max
,count(if(D_68 is null, D_68, null)) as D_68_cnt_null
,count(if(D_68 = 0, D_68, null)) as D_68_cnt_0
,count(if(D_68 = 1, D_68, null)) as D_68_cnt_1
,count(if(D_68 = 2, D_68, null)) as D_68_cnt_2
,count(if(D_68 = 3, D_68, null)) as D_68_cnt_3
,count(if(D_68 = 4, D_68, null)) as D_68_cnt_4
,count(if(D_68 = 5, D_68, null)) as D_68_cnt_5
,count(if(D_68 = 6, D_68, null)) as D_68_cnt_6
,min(S_12) as S_12_min,max(S_12) as S_12_max
,min(R_6) as R_6_min,max(R_6) as R_6_max
,min(S_13) as S_13_min,max(S_13) as S_13_max
,min(B_21) as B_21_min,max(B_21) as B_21_max
,min(D_69) as D_69_min,max(D_69) as D_69_max
,min(B_22) as B_22_min,max(B_22) as B_22_max
,min(D_70) as D_70_min,max(D_70) as D_70_max
,min(D_71) as D_71_min,max(D_71) as D_71_max
,min(D_72) as D_72_min,max(D_72) as D_72_max
,min(S_15) as S_15_min,max(S_15) as S_15_max
,min(B_23) as B_23_min,max(B_23) as B_23_max
,min(D_73) as D_73_min,max(D_73) as D_73_max
,min(P_4) as P_4_min,max(P_4) as P_4_max
,min(D_74) as D_74_min,max(D_74) as D_74_max
,min(D_75) as D_75_min,max(D_75) as D_75_max
,min(D_76) as D_76_min,max(D_76) as D_76_max
,min(B_24) as B_24_min,max(B_24) as B_24_max
,min(R_7) as R_7_min,max(R_7) as R_7_max
,min(D_77) as D_77_min,max(D_77) as D_77_max
,min(B_25) as B_25_min,max(B_25) as B_25_max
,min(B_26) as B_26_min,max(B_26) as B_26_max
,min(D_78) as D_78_min,max(D_78) as D_78_max
,min(D_79) as D_79_min,max(D_79) as D_79_max
,min(R_8) as R_8_min,max(R_8) as R_8_max
,min(R_9) as R_9_min,max(R_9) as R_9_max
,min(S_16) as S_16_min,max(S_16) as S_16_max
,min(D_80) as D_80_min,max(D_80) as D_80_max
,min(R_10) as R_10_min,max(R_10) as R_10_max
,min(R_11) as R_11_min,max(R_11) as R_11_max
,min(B_27) as B_27_min,max(B_27) as B_27_max
,min(D_81) as D_81_min,max(D_81) as D_81_max
,min(D_82) as D_82_min,max(D_82) as D_82_max
,min(S_17) as S_17_min,max(S_17) as S_17_max
,min(R_12) as R_12_min,max(R_12) as R_12_max
,min(B_28) as B_28_min,max(B_28) as B_28_max
,min(R_13) as R_13_min,max(R_13) as R_13_max
,min(D_83) as D_83_min,max(D_83) as D_83_max
,min(R_14) as R_14_min,max(R_14) as R_14_max
,min(R_15) as R_15_min,max(R_15) as R_15_max
,min(D_84) as D_84_min,max(D_84) as D_84_max
,min(R_16) as R_16_min,max(R_16) as R_16_max
,min(B_29) as B_29_min,max(B_29) as B_29_max
,count(if(B_30 is null, B_30, null)) as B_30_cnt_null
,count(if(B_30 = 0, B_30, null)) as B_30_cnt_0
,count(if(B_30 = 1, B_30, null)) as B_30_cnt_1
,count(if(B_30 = 2, B_30, null)) as B_30_cnt_2
,count(if(B_30 = 3, B_30, null)) as B_30_cnt_3
,min(S_18) as S_18_min,max(S_18) as S_18_max
,min(D_86) as D_86_min,max(D_86) as D_86_max
,min(D_87) as D_87_min,max(D_87) as D_87_max
,min(R_17) as R_17_min,max(R_17) as R_17_max
,min(R_18) as R_18_min,max(R_18) as R_18_max
,min(D_88) as D_88_min,max(D_88) as D_88_max
,min(B_31) as B_31_min,max(B_31) as B_31_max
,min(S_19) as S_19_min,max(S_19) as S_19_max
,min(R_19) as R_19_min,max(R_19) as R_19_max
,min(B_32) as B_32_min,max(B_32) as B_32_max
,min(S_20) as S_20_min,max(S_20) as S_20_max
,min(R_20) as R_20_min,max(R_20) as R_20_max
,min(R_21) as R_21_min,max(R_21) as R_21_max
,min(B_33) as B_33_min,max(B_33) as B_33_max
,min(D_89) as D_89_min,max(D_89) as D_89_max
,min(R_22) as R_22_min,max(R_22) as R_22_max
,min(R_23) as R_23_min,max(R_23) as R_23_max
,min(D_91) as D_91_min,max(D_91) as D_91_max
,min(D_92) as D_92_min,max(D_92) as D_92_max
,min(D_93) as D_93_min,max(D_93) as D_93_max
,min(D_94) as D_94_min,max(D_94) as D_94_max
,min(R_24) as R_24_min,max(R_24) as R_24_max
,min(R_25) as R_25_min,max(R_25) as R_25_max
,min(D_96) as D_96_min,max(D_96) as D_96_max
,min(S_22) as S_22_min,max(S_22) as S_22_max
,min(S_23) as S_23_min,max(S_23) as S_23_max
,min(S_24) as S_24_min,max(S_24) as S_24_max
,min(S_25) as S_25_min,max(S_25) as S_25_max
,min(S_26) as S_26_min,max(S_26) as S_26_max
,min(D_102) as D_102_min,max(D_102) as D_102_max
,min(D_103) as D_103_min,max(D_103) as D_103_max
,min(D_104) as D_104_min,max(D_104) as D_104_max
,min(D_105) as D_105_min,max(D_105) as D_105_max
,min(D_106) as D_106_min,max(D_106) as D_106_max
,min(D_107) as D_107_min,max(D_107) as D_107_max
,min(B_36) as B_36_min,max(B_36) as B_36_max
,min(B_37) as B_37_min,max(B_37) as B_37_max
,min(R_26) as R_26_min,max(R_26) as R_26_max
,min(R_27) as R_27_min,max(R_27) as R_27_max
,count(if(B_38 is null, B_38, null)) as B_38_cnt_null
,count(if(B_38 = 0, B_38, null)) as B_38_cnt_0
,count(if(B_38 = 1, B_38, null)) as B_38_cnt_1
,count(if(B_38 = 2, B_38, null)) as B_38_cnt_2
,count(if(B_38 = 3, B_38, null)) as B_38_cnt_3
,count(if(B_38 = 4, B_38, null)) as B_38_cnt_4
,count(if(B_38 = 5, B_38, null)) as B_38_cnt_5
,count(if(B_38 = 6, B_38, null)) as B_38_cnt_6
,count(if(B_38 = 7, B_38, null)) as B_38_cnt_7
,min(D_108) as D_108_min,max(D_108) as D_108_max
,min(D_109) as D_109_min,max(D_109) as D_109_max
,min(D_110) as D_110_min,max(D_110) as D_110_max
,min(D_111) as D_111_min,max(D_111) as D_111_max
,min(B_39) as B_39_min,max(B_39) as B_39_max
,min(D_112) as D_112_min,max(D_112) as D_112_max
,min(B_40) as B_40_min,max(B_40) as B_40_max
,min(S_27) as S_27_min,max(S_27) as S_27_max
,min(D_113) as D_113_min,max(D_113) as D_113_max
,count(if(D_114 is null, D_114, null)) as D_114_cnt_null
,count(if(D_114 = 0, D_114, null)) as D_114_cnt_0
,count(if(D_114 = 1, D_114, null)) as D_114_cnt_1
,min(D_115) as D_115_min,max(D_115) as D_115_max
,count(if(D_116 is null, D_116, null)) as D_116_cnt_null
,count(if(D_116 = 0, D_116, null)) as D_116_cnt_0
,count(if(D_116 = 1, D_116, null)) as D_116_cnt_1
,count(if(D_117 is null, D_117, null)) as D_117_cnt_null
,count(if(D_117 = -1, D_117, null)) as D_117_cnt_m1
,count(if(D_117 = 1, D_117, null)) as D_117_cnt_1
,count(if(D_117 = 2, D_117, null)) as D_117_cnt_2
,count(if(D_117 = 3, D_117, null)) as D_117_cnt_3
,count(if(D_117 = 4, D_117, null)) as D_117_cnt_4
,count(if(D_117 = 5, D_117, null)) as D_117_cnt_5
,count(if(D_117 = 6, D_117, null)) as D_117_cnt_6
,min(D_118) as D_118_min,max(D_118) as D_118_max
,min(D_119) as D_119_min,max(D_119) as D_119_max
,count(if(D_120 is null, D_120, null)) as D_120_cnt_null
,count(if(D_120 = 0, D_120, null)) as D_120_cnt_0
,count(if(D_120 = 1, D_120, null)) as D_120_cnt_1
,min(D_121) as D_121_min,max(D_121) as D_121_max
,min(D_122) as D_122_min,max(D_122) as D_122_max
,min(D_123) as D_123_min,max(D_123) as D_123_max
,min(D_124) as D_124_min,max(D_124) as D_124_max
,min(D_125) as D_125_min,max(D_125) as D_125_max
,count(if(D_126 is null, D_126, null)) as D_126_cnt_null
,count(if(D_126 = -1, D_126, null)) as D_126_cnt_m1
,count(if(D_126 = 0, D_126, null)) as D_126_cnt_0
,count(if(D_126 = 1, D_126, null)) as D_126_cnt_1
,min(D_127) as D_127_min,max(D_127) as D_127_max
,min(D_128) as D_128_min,max(D_128) as D_128_max
,min(D_129) as D_129_min,max(D_129) as D_129_max
,min(B_41) as B_41_min,max(B_41) as B_41_max
,min(B_42) as B_42_min,max(B_42) as B_42_max
,min(D_130) as D_130_min,max(D_130) as D_130_max
,min(D_131) as D_131_min,max(D_131) as D_131_max
,min(D_132) as D_132_min,max(D_132) as D_132_max
,min(D_133) as D_133_min,max(D_133) as D_133_max
,min(R_28) as R_28_min,max(R_28) as R_28_max
,min(D_134) as D_134_min,max(D_134) as D_134_max
,min(D_135) as D_135_min,max(D_135) as D_135_max
,min(D_136) as D_136_min,max(D_136) as D_136_max
,min(D_137) as D_137_min,max(D_137) as D_137_max
,min(D_138) as D_138_min,max(D_138) as D_138_max
,min(D_139) as D_139_min,max(D_139) as D_139_max
,min(D_140) as D_140_min,max(D_140) as D_140_max
,min(D_141) as D_141_min,max(D_141) as D_141_max
,min(D_142) as D_142_min,max(D_142) as D_142_max
,min(D_143) as D_143_min,max(D_143) as D_143_max
,min(D_144) as D_144_min,max(D_144) as D_144_max
,min(D_145) as D_145_min,max(D_145) as D_145_max


-- FROM `black-sanctum-358708.kaggle_amex.train_data_100000` 
-- FROM `black-sanctum-358708.kaggle_amex.train_data` 
-- FROM `black-sanctum-358708.kaggle_amex.test_data_100000` 
FROM `black-sanctum-358708.kaggle_amex.test_data` 

group by customer_ID

order by customer_ID

--  LIMIT 1000
