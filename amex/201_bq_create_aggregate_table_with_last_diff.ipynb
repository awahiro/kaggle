# %% [markdown]
# ## BigQueryにて集計データを出力するSQL
#
# ### 以下の項目を追加したバージョン
#
# - Custmer_IDごとの最終値
# - Custmer_IDごとの最終値と平均のdiffを追加

# %%
# -- kaggle amex - 集約表作成SQL 
-- categorical:['B_30', 'B_38', 'D_114', 'D_116', 'D_117', 'D_120', 'D_126', 'D_63', 'D_64', 'D_66', 'D_68

-- kaggle amex - train 集約表作成SQL 
-- categorical:['B_30', 'B_38', 'D_114', 'D_116', 'D_117', 'D_120', 'D_126', 'D_63', 'D_64', 'D_66', 'D_68

SELECT

customer_ID
,count(S_2) as count
,min(S_2) as S_2_min, max(S_2) as S_2_max
,date_diff(max(S_2), min(S_2), DAY) as S_2_days
,min(P_2) as P_2_min,max(P_2) as P_2_max, avg(P_2) as P_2_avg
,min(D_39) as D_39_min,max(D_39) as D_39_max, avg(D_39) as D_39_avg
,min(B_1) as B_1_min,max(B_1) as B_1_max, avg(B_1) as B_1_avg
,min(B_2) as B_2_min,max(B_2) as B_2_max, avg(B_2) as B_2_avg
,min(R_1) as R_1_min,max(R_1) as R_1_max, avg(R_1) as R_1_avg
,min(S_3) as S_3_min,max(S_3) as S_3_max, avg(S_3) as S_3_avg
,min(D_41) as D_41_min,max(D_41) as D_41_max, avg(D_41) as D_41_avg
,min(B_3) as B_3_min,max(B_3) as B_3_max, avg(B_3) as B_3_avg
,min(D_42) as D_42_min,max(D_42) as D_42_max, avg(D_42) as D_42_avg
,min(D_43) as D_43_min,max(D_43) as D_43_max, avg(D_43) as D_43_avg
,min(D_44) as D_44_min,max(D_44) as D_44_max, avg(D_44) as D_44_avg
,min(B_4) as B_4_min,max(B_4) as B_4_max, avg(B_4) as B_4_avg
,min(D_45) as D_45_min,max(D_45) as D_45_max, avg(D_45) as D_45_avg
,min(B_5) as B_5_min,max(B_5) as B_5_max, avg(B_5) as B_5_avg
,min(R_2) as R_2_min,max(R_2) as R_2_max, avg(R_2) as R_2_avg
,min(D_46) as D_46_min,max(D_46) as D_46_max, avg(D_46) as D_46_avg
,min(D_47) as D_47_min,max(D_47) as D_47_max, avg(D_47) as D_47_avg
,min(D_48) as D_48_min,max(D_48) as D_48_max, avg(D_48) as D_48_avg
,min(D_49) as D_49_min,max(D_49) as D_49_max, avg(D_49) as D_49_avg
,min(B_6) as B_6_min,max(B_6) as B_6_max, avg(B_6) as B_6_avg
,min(B_7) as B_7_min,max(B_7) as B_7_max, avg(B_7) as B_7_avg
,min(B_8) as B_8_min,max(B_8) as B_8_max, avg(B_8) as B_8_avg
,min(D_50) as D_50_min,max(D_50) as D_50_max, avg(D_50) as D_50_avg
,min(D_51) as D_51_min,max(D_51) as D_51_max, avg(D_51) as D_51_avg
,min(B_9) as B_9_min,max(B_9) as B_9_max, avg(B_9) as B_9_avg
,min(R_3) as R_3_min,max(R_3) as R_3_max, avg(R_3) as R_3_avg
,min(D_52) as D_52_min,max(D_52) as D_52_max, avg(D_52) as D_52_avg
,min(P_3) as P_3_min,max(P_3) as P_3_max, avg(P_3) as P_3_avg
,min(B_10) as B_10_min,max(B_10) as B_10_max, avg(B_10) as B_10_avg
,min(D_53) as D_53_min,max(D_53) as D_53_max, avg(D_53) as D_53_avg
,min(S_5) as S_5_min,max(S_5) as S_5_max, avg(S_5) as S_5_avg
,min(B_11) as B_11_min,max(B_11) as B_11_max, avg(B_11) as B_11_avg
,min(S_6) as S_6_min,max(S_6) as S_6_max, avg(S_6) as S_6_avg
,min(D_54) as D_54_min,max(D_54) as D_54_max, avg(D_54) as D_54_avg
,min(R_4) as R_4_min,max(R_4) as R_4_max, avg(R_4) as R_4_avg
,min(S_7) as S_7_min,max(S_7) as S_7_max, avg(S_7) as S_7_avg
,min(B_12) as B_12_min,max(B_12) as B_12_max, avg(B_12) as B_12_avg
,min(S_8) as S_8_min,max(S_8) as S_8_max, avg(S_8) as S_8_avg
,min(D_55) as D_55_min,max(D_55) as D_55_max, avg(D_55) as D_55_avg
,min(D_56) as D_56_min,max(D_56) as D_56_max, avg(D_56) as D_56_avg
,min(B_13) as B_13_min,max(B_13) as B_13_max, avg(B_13) as B_13_avg
,min(R_5) as R_5_min,max(R_5) as R_5_max, avg(R_5) as R_5_avg
,min(D_58) as D_58_min,max(D_58) as D_58_max, avg(D_58) as D_58_avg
,min(S_9) as S_9_min,max(S_9) as S_9_max, avg(S_9) as S_9_avg
,min(B_14) as B_14_min,max(B_14) as B_14_max, avg(B_14) as B_14_avg
,min(D_59) as D_59_min,max(D_59) as D_59_max, avg(D_59) as D_59_avg
,min(D_60) as D_60_min,max(D_60) as D_60_max, avg(D_60) as D_60_avg
,min(D_61) as D_61_min,max(D_61) as D_61_max, avg(D_61) as D_61_avg
,min(B_15) as B_15_min,max(B_15) as B_15_max, avg(B_15) as B_15_avg
,min(S_11) as S_11_min,max(S_11) as S_11_max, avg(S_11) as S_11_avg
,min(D_62) as D_62_min,max(D_62) as D_62_max, avg(D_62) as D_62_avg
,count(if(D_63 is null, D_63, null)) as D_63_cnt_null
,count(if(D_63 = 'CL', D_63, null)) as D_63_cnt_CL
,count(if(D_63 = 'CO', D_63, null)) as D_63_cnt_CO
,count(if(D_63 = 'CR', D_63, null)) as D_63_cnt_CR
,count(if(D_63 = 'XL', D_63, null)) as D_63_cnt_XL
,count(if(D_63 = 'XM', D_63, null)) as D_63_cnt_XM
,count(if(D_63 = 'XZ', D_63, null)) as D_63_cnt_XZ
,count(if(D_64 is null, D_64, null)) as D_64_cnt_null
,count(if(D_64 = '-1', D_64, null)) as D_64_cnt_m1
,count(if(D_64 = 'O', D_64, null)) as D_64_cnt_O
,count(if(D_64 = 'R', D_64, null)) as D_64_cnt_R
,count(if(D_64 = 'U', D_64, null)) as D_64_cnt_U
,min(D_65) as D_65_min,max(D_65) as D_65_max, avg(D_65) as D_65_avg
,min(B_16) as B_16_min,max(B_16) as B_16_max, avg(B_16) as B_16_avg
,min(B_17) as B_17_min,max(B_17) as B_17_max, avg(B_17) as B_17_avg
,min(B_18) as B_18_min,max(B_18) as B_18_max, avg(B_18) as B_18_avg
,min(B_19) as B_19_min,max(B_19) as B_19_max, avg(B_19) as B_19_avg
,count(if(D_66 is null, D_66, null)) as D_66_cnt_null
,count(if(D_66 = 0, D_66, null)) as D_66_cnt_0
,count(if(D_66 = 1, D_66, null)) as D_66_cnt_1
,min(B_20) as B_20_min,max(B_20) as B_20_max, avg(B_20) as B_20_avg
,count(if(D_68 is null, D_68, null)) as D_68_cnt_null
,count(if(D_68 = 0, D_68, null)) as D_68_cnt_0
,count(if(D_68 = 1, D_68, null)) as D_68_cnt_1
,count(if(D_68 = 2, D_68, null)) as D_68_cnt_2
,count(if(D_68 = 3, D_68, null)) as D_68_cnt_3
,count(if(D_68 = 4, D_68, null)) as D_68_cnt_4
,count(if(D_68 = 5, D_68, null)) as D_68_cnt_5
,count(if(D_68 = 6, D_68, null)) as D_68_cnt_6
,min(S_12) as S_12_min,max(S_12) as S_12_max, avg(S_12) as S_12_avg
,min(R_6) as R_6_min,max(R_6) as R_6_max, avg(R_6) as R_6_avg
,min(S_13) as S_13_min,max(S_13) as S_13_max, avg(S_13) as S_13_avg
,min(B_21) as B_21_min,max(B_21) as B_21_max, avg(B_21) as B_21_avg
,min(D_69) as D_69_min,max(D_69) as D_69_max, avg(D_69) as D_69_avg
,min(B_22) as B_22_min,max(B_22) as B_22_max, avg(B_22) as B_22_avg
,min(D_70) as D_70_min,max(D_70) as D_70_max, avg(D_70) as D_70_avg
,min(D_71) as D_71_min,max(D_71) as D_71_max, avg(D_71) as D_71_avg
,min(D_72) as D_72_min,max(D_72) as D_72_max, avg(D_72) as D_72_avg
,min(S_15) as S_15_min,max(S_15) as S_15_max, avg(S_15) as S_15_avg
,min(B_23) as B_23_min,max(B_23) as B_23_max, avg(B_23) as B_23_avg
,min(D_73) as D_73_min,max(D_73) as D_73_max, avg(D_73) as D_73_avg
,min(P_4) as P_4_min,max(P_4) as P_4_max, avg(P_4) as P_4_avg
,min(D_74) as D_74_min,max(D_74) as D_74_max, avg(D_74) as D_74_avg
,min(D_75) as D_75_min,max(D_75) as D_75_max, avg(D_75) as D_75_avg
,min(D_76) as D_76_min,max(D_76) as D_76_max, avg(D_76) as D_76_avg
,min(B_24) as B_24_min,max(B_24) as B_24_max, avg(B_24) as B_24_avg
,min(R_7) as R_7_min,max(R_7) as R_7_max, avg(R_7) as R_7_avg
,min(D_77) as D_77_min,max(D_77) as D_77_max, avg(D_77) as D_77_avg
,min(B_25) as B_25_min,max(B_25) as B_25_max, avg(B_25) as B_25_avg
,min(B_26) as B_26_min,max(B_26) as B_26_max, avg(B_26) as B_26_avg
,min(D_78) as D_78_min,max(D_78) as D_78_max, avg(D_78) as D_78_avg
,min(D_79) as D_79_min,max(D_79) as D_79_max, avg(D_79) as D_79_avg
,min(R_8) as R_8_min,max(R_8) as R_8_max, avg(R_8) as R_8_avg
,min(R_9) as R_9_min,max(R_9) as R_9_max, avg(R_9) as R_9_avg
,min(S_16) as S_16_min,max(S_16) as S_16_max, avg(S_16) as S_16_avg
,min(D_80) as D_80_min,max(D_80) as D_80_max, avg(D_80) as D_80_avg
,min(R_10) as R_10_min,max(R_10) as R_10_max, avg(R_10) as R_10_avg
,min(R_11) as R_11_min,max(R_11) as R_11_max, avg(R_11) as R_11_avg
,min(B_27) as B_27_min,max(B_27) as B_27_max, avg(B_27) as B_27_avg
,min(D_81) as D_81_min,max(D_81) as D_81_max, avg(D_81) as D_81_avg
,min(D_82) as D_82_min,max(D_82) as D_82_max, avg(D_82) as D_82_avg
,min(S_17) as S_17_min,max(S_17) as S_17_max, avg(S_17) as S_17_avg
,min(R_12) as R_12_min,max(R_12) as R_12_max, avg(R_12) as R_12_avg
,min(B_28) as B_28_min,max(B_28) as B_28_max, avg(B_28) as B_28_avg
,min(R_13) as R_13_min,max(R_13) as R_13_max, avg(R_13) as R_13_avg
,min(D_83) as D_83_min,max(D_83) as D_83_max, avg(D_83) as D_83_avg
,min(R_14) as R_14_min,max(R_14) as R_14_max, avg(R_14) as R_14_avg
,min(R_15) as R_15_min,max(R_15) as R_15_max, avg(R_15) as R_15_avg
,min(D_84) as D_84_min,max(D_84) as D_84_max, avg(D_84) as D_84_avg
,min(R_16) as R_16_min,max(R_16) as R_16_max, avg(R_16) as R_16_avg
,min(B_29) as B_29_min,max(B_29) as B_29_max, avg(B_29) as B_29_avg
,count(if(B_30 is null, B_30, null)) as B_30_cnt_null
,count(if(B_30 = 0, B_30, null)) as B_30_cnt_0
,count(if(B_30 = 1, B_30, null)) as B_30_cnt_1
,count(if(B_30 = 2, B_30, null)) as B_30_cnt_2
,count(if(B_30 = 3, B_30, null)) as B_30_cnt_3
,min(S_18) as S_18_min,max(S_18) as S_18_max, avg(S_18) as S_18_avg
,min(D_86) as D_86_min,max(D_86) as D_86_max, avg(D_86) as D_86_avg
,min(D_87) as D_87_min,max(D_87) as D_87_max, avg(D_87) as D_87_avg
,min(R_17) as R_17_min,max(R_17) as R_17_max, avg(R_17) as R_17_avg
,min(R_18) as R_18_min,max(R_18) as R_18_max, avg(R_18) as R_18_avg
,min(D_88) as D_88_min,max(D_88) as D_88_max, avg(D_88) as D_88_avg
,min(B_31) as B_31_min,max(B_31) as B_31_max, avg(B_31) as B_31_avg
,min(S_19) as S_19_min,max(S_19) as S_19_max, avg(S_19) as S_19_avg
,min(R_19) as R_19_min,max(R_19) as R_19_max, avg(R_19) as R_19_avg
,min(B_32) as B_32_min,max(B_32) as B_32_max, avg(B_32) as B_32_avg
,min(S_20) as S_20_min,max(S_20) as S_20_max, avg(S_20) as S_20_avg
,min(R_20) as R_20_min,max(R_20) as R_20_max, avg(R_20) as R_20_avg
,min(R_21) as R_21_min,max(R_21) as R_21_max, avg(R_21) as R_21_avg
,min(B_33) as B_33_min,max(B_33) as B_33_max, avg(B_33) as B_33_avg
,min(D_89) as D_89_min,max(D_89) as D_89_max, avg(D_89) as D_89_avg
,min(R_22) as R_22_min,max(R_22) as R_22_max, avg(R_22) as R_22_avg
,min(R_23) as R_23_min,max(R_23) as R_23_max, avg(R_23) as R_23_avg
,min(D_91) as D_91_min,max(D_91) as D_91_max, avg(D_91) as D_91_avg
,min(D_92) as D_92_min,max(D_92) as D_92_max, avg(D_92) as D_92_avg
,min(D_93) as D_93_min,max(D_93) as D_93_max, avg(D_93) as D_93_avg
,min(D_94) as D_94_min,max(D_94) as D_94_max, avg(D_94) as D_94_avg
,min(R_24) as R_24_min,max(R_24) as R_24_max, avg(R_24) as R_24_avg
,min(R_25) as R_25_min,max(R_25) as R_25_max, avg(R_25) as R_25_avg
,min(D_96) as D_96_min,max(D_96) as D_96_max, avg(D_96) as D_96_avg
,min(S_22) as S_22_min,max(S_22) as S_22_max, avg(S_22) as S_22_avg
,min(S_23) as S_23_min,max(S_23) as S_23_max, avg(S_23) as S_23_avg
,min(S_24) as S_24_min,max(S_24) as S_24_max, avg(S_24) as S_24_avg
,min(S_25) as S_25_min,max(S_25) as S_25_max, avg(S_25) as S_25_avg
,min(S_26) as S_26_min,max(S_26) as S_26_max, avg(S_26) as S_26_avg
,min(D_102) as D_102_min,max(D_102) as D_102_max, avg(D_102) as D_102_avg
,min(D_103) as D_103_min,max(D_103) as D_103_max, avg(D_103) as D_103_avg
,min(D_104) as D_104_min,max(D_104) as D_104_max, avg(D_104) as D_104_avg
,min(D_105) as D_105_min,max(D_105) as D_105_max, avg(D_105) as D_105_avg
,min(D_106) as D_106_min,max(D_106) as D_106_max, avg(D_106) as D_106_avg
,min(D_107) as D_107_min,max(D_107) as D_107_max, avg(D_107) as D_107_avg
,min(B_36) as B_36_min,max(B_36) as B_36_max, avg(B_36) as B_36_avg
,min(B_37) as B_37_min,max(B_37) as B_37_max, avg(B_37) as B_37_avg
,min(R_26) as R_26_min,max(R_26) as R_26_max, avg(R_26) as R_26_avg
,min(R_27) as R_27_min,max(R_27) as R_27_max, avg(R_27) as R_27_avg
,count(if(B_38 is null, B_38, null)) as B_38_cnt_null
,count(if(B_38 = 0, B_38, null)) as B_38_cnt_0
,count(if(B_38 = 1, B_38, null)) as B_38_cnt_1
,count(if(B_38 = 2, B_38, null)) as B_38_cnt_2
,count(if(B_38 = 3, B_38, null)) as B_38_cnt_3
,count(if(B_38 = 4, B_38, null)) as B_38_cnt_4
,count(if(B_38 = 5, B_38, null)) as B_38_cnt_5
,count(if(B_38 = 6, B_38, null)) as B_38_cnt_6
,count(if(B_38 = 7, B_38, null)) as B_38_cnt_7
,min(D_108) as D_108_min,max(D_108) as D_108_max, avg(D_108) as D_108_avg
,min(D_109) as D_109_min,max(D_109) as D_109_max, avg(D_109) as D_109_avg
,min(D_110) as D_110_min,max(D_110) as D_110_max, avg(D_110) as D_110_avg
,min(D_111) as D_111_min,max(D_111) as D_111_max, avg(D_111) as D_111_avg
,min(B_39) as B_39_min,max(B_39) as B_39_max, avg(B_39) as B_39_avg
,min(D_112) as D_112_min,max(D_112) as D_112_max, avg(D_112) as D_112_avg
,min(B_40) as B_40_min,max(B_40) as B_40_max, avg(B_40) as B_40_avg
,min(S_27) as S_27_min,max(S_27) as S_27_max, avg(S_27) as S_27_avg
,min(D_113) as D_113_min,max(D_113) as D_113_max, avg(D_113) as D_113_avg
,count(if(D_114 is null, D_114, null)) as D_114_cnt_null
,count(if(D_114 = 0, D_114, null)) as D_114_cnt_0
,count(if(D_114 = 1, D_114, null)) as D_114_cnt_1
,min(D_115) as D_115_min,max(D_115) as D_115_max, avg(D_115) as D_115_avg
,count(if(D_116 is null, D_116, null)) as D_116_cnt_null
,count(if(D_116 = 0, D_116, null)) as D_116_cnt_0
,count(if(D_116 = 1, D_116, null)) as D_116_cnt_1
,count(if(D_117 is null, D_117, null)) as D_117_cnt_null
,count(if(D_117 = -1, D_117, null)) as D_117_cnt_m1
,count(if(D_117 = 1, D_117, null)) as D_117_cnt_1
,count(if(D_117 = 2, D_117, null)) as D_117_cnt_2
,count(if(D_117 = 3, D_117, null)) as D_117_cnt_3
,count(if(D_117 = 4, D_117, null)) as D_117_cnt_4
,count(if(D_117 = 5, D_117, null)) as D_117_cnt_5
,count(if(D_117 = 6, D_117, null)) as D_117_cnt_6
,min(D_118) as D_118_min,max(D_118) as D_118_max, avg(D_118) as D_118_avg
,min(D_119) as D_119_min,max(D_119) as D_119_max, avg(D_119) as D_119_avg
,count(if(D_120 is null, D_120, null)) as D_120_cnt_null
,count(if(D_120 = 0, D_120, null)) as D_120_cnt_0
,count(if(D_120 = 1, D_120, null)) as D_120_cnt_1
,min(D_121) as D_121_min,max(D_121) as D_121_max, avg(D_121) as D_121_avg
,min(D_122) as D_122_min,max(D_122) as D_122_max, avg(D_122) as D_122_avg
,min(D_123) as D_123_min,max(D_123) as D_123_max, avg(D_123) as D_123_avg
,min(D_124) as D_124_min,max(D_124) as D_124_max, avg(D_124) as D_124_avg
,min(D_125) as D_125_min,max(D_125) as D_125_max, avg(D_125) as D_125_avg
,count(if(D_126 is null, D_126, null)) as D_126_cnt_null
,count(if(D_126 = -1, D_126, null)) as D_126_cnt_m1
,count(if(D_126 = 0, D_126, null)) as D_126_cnt_0
,count(if(D_126 = 1, D_126, null)) as D_126_cnt_1
,min(D_127) as D_127_min,max(D_127) as D_127_max, avg(D_127) as D_127_avg
,min(D_128) as D_128_min,max(D_128) as D_128_max, avg(D_128) as D_128_avg
,min(D_129) as D_129_min,max(D_129) as D_129_max, avg(D_129) as D_129_avg
,min(B_41) as B_41_min,max(B_41) as B_41_max, avg(B_41) as B_41_avg
,min(B_42) as B_42_min,max(B_42) as B_42_max, avg(B_42) as B_42_avg
,min(D_130) as D_130_min,max(D_130) as D_130_max, avg(D_130) as D_130_avg
,min(D_131) as D_131_min,max(D_131) as D_131_max, avg(D_131) as D_131_avg
,min(D_132) as D_132_min,max(D_132) as D_132_max, avg(D_132) as D_132_avg
,min(D_133) as D_133_min,max(D_133) as D_133_max, avg(D_133) as D_133_avg
,min(R_28) as R_28_min,max(R_28) as R_28_max, avg(R_28) as R_28_avg
,min(D_134) as D_134_min,max(D_134) as D_134_max, avg(D_134) as D_134_avg
,min(D_135) as D_135_min,max(D_135) as D_135_max, avg(D_135) as D_135_avg
,min(D_136) as D_136_min,max(D_136) as D_136_max, avg(D_136) as D_136_avg
,min(D_137) as D_137_min,max(D_137) as D_137_max, avg(D_137) as D_137_avg
,min(D_138) as D_138_min,max(D_138) as D_138_max, avg(D_138) as D_138_avg
,min(D_139) as D_139_min,max(D_139) as D_139_max, avg(D_139) as D_139_avg
,min(D_140) as D_140_min,max(D_140) as D_140_max, avg(D_140) as D_140_avg
,min(D_141) as D_141_min,max(D_141) as D_141_max, avg(D_141) as D_141_avg
,min(D_142) as D_142_min,max(D_142) as D_142_max, avg(D_142) as D_142_avg
,min(D_143) as D_143_min,max(D_143) as D_143_max, avg(D_143) as D_143_avg
,min(D_144) as D_144_min,max(D_144) as D_144_max, avg(D_144) as D_144_avg
,min(D_145) as D_145_min,max(D_145) as D_145_max, avg(D_145) as D_145_avg

,max(P_2_last) as P_2_last ,max(P_2_last) - avg(P_2) as P_2_ldiff
,max(D_39_last) as D_39_last ,max(D_39_last) - avg(D_39) as D_39_ldiff
,max(B_1_last) as B_1_last ,max(B_1_last) - avg(B_1) as B_1_ldiff
,max(B_2_last) as B_2_last ,max(B_2_last) - avg(B_2) as B_2_ldiff
,max(R_1_last) as R_1_last ,max(R_1_last) - avg(R_1) as R_1_ldiff
,max(S_3_last) as S_3_last ,max(S_3_last) - avg(S_3) as S_3_ldiff
,max(D_41_last) as D_41_last ,max(D_41_last) - avg(D_41) as D_41_ldiff
,max(B_3_last) as B_3_last ,max(B_3_last) - avg(B_3) as B_3_ldiff
,max(D_42_last) as D_42_last ,max(D_42_last) - avg(D_42) as D_42_ldiff
,max(D_43_last) as D_43_last ,max(D_43_last) - avg(D_43) as D_43_ldiff
,max(D_44_last) as D_44_last ,max(D_44_last) - avg(D_44) as D_44_ldiff
,max(B_4_last) as B_4_last ,max(B_4_last) - avg(B_4) as B_4_ldiff
,max(D_45_last) as D_45_last ,max(D_45_last) - avg(D_45) as D_45_ldiff
,max(B_5_last) as B_5_last ,max(B_5_last) - avg(B_5) as B_5_ldiff
,max(R_2_last) as R_2_last ,max(R_2_last) - avg(R_2) as R_2_ldiff
,max(D_46_last) as D_46_last ,max(D_46_last) - avg(D_46) as D_46_ldiff
,max(D_47_last) as D_47_last ,max(D_47_last) - avg(D_47) as D_47_ldiff
,max(D_48_last) as D_48_last ,max(D_48_last) - avg(D_48) as D_48_ldiff
,max(D_49_last) as D_49_last ,max(D_49_last) - avg(D_49) as D_49_ldiff
,max(B_6_last) as B_6_last ,max(B_6_last) - avg(B_6) as B_6_ldiff
,max(B_7_last) as B_7_last ,max(B_7_last) - avg(B_7) as B_7_ldiff
,max(B_8_last) as B_8_last ,max(B_8_last) - avg(B_8) as B_8_ldiff
,max(D_50_last) as D_50_last ,max(D_50_last) - avg(D_50) as D_50_ldiff
,max(D_51_last) as D_51_last ,max(D_51_last) - avg(D_51) as D_51_ldiff
,max(B_9_last) as B_9_last ,max(B_9_last) - avg(B_9) as B_9_ldiff
,max(R_3_last) as R_3_last ,max(R_3_last) - avg(R_3) as R_3_ldiff
,max(D_52_last) as D_52_last ,max(D_52_last) - avg(D_52) as D_52_ldiff
,max(P_3_last) as P_3_last ,max(P_3_last) - avg(P_3) as P_3_ldiff
,max(B_10_last) as B_10_last ,max(B_10_last) - avg(B_10) as B_10_ldiff
,max(D_53_last) as D_53_last ,max(D_53_last) - avg(D_53) as D_53_ldiff
,max(S_5_last) as S_5_last ,max(S_5_last) - avg(S_5) as S_5_ldiff
,max(B_11_last) as B_11_last ,max(B_11_last) - avg(B_11) as B_11_ldiff
,max(S_6_last) as S_6_last ,max(S_6_last) - avg(S_6) as S_6_ldiff
,max(D_54_last) as D_54_last ,max(D_54_last) - avg(D_54) as D_54_ldiff
,max(R_4_last) as R_4_last ,max(R_4_last) - avg(R_4) as R_4_ldiff
,max(S_7_last) as S_7_last ,max(S_7_last) - avg(S_7) as S_7_ldiff
,max(B_12_last) as B_12_last ,max(B_12_last) - avg(B_12) as B_12_ldiff
,max(S_8_last) as S_8_last ,max(S_8_last) - avg(S_8) as S_8_ldiff
,max(D_55_last) as D_55_last ,max(D_55_last) - avg(D_55) as D_55_ldiff
,max(D_56_last) as D_56_last ,max(D_56_last) - avg(D_56) as D_56_ldiff
,max(B_13_last) as B_13_last ,max(B_13_last) - avg(B_13) as B_13_ldiff
,max(R_5_last) as R_5_last ,max(R_5_last) - avg(R_5) as R_5_ldiff
,max(D_58_last) as D_58_last ,max(D_58_last) - avg(D_58) as D_58_ldiff
,max(S_9_last) as S_9_last ,max(S_9_last) - avg(S_9) as S_9_ldiff
,max(B_14_last) as B_14_last ,max(B_14_last) - avg(B_14) as B_14_ldiff
,max(D_59_last) as D_59_last ,max(D_59_last) - avg(D_59) as D_59_ldiff
,max(D_60_last) as D_60_last ,max(D_60_last) - avg(D_60) as D_60_ldiff
,max(D_61_last) as D_61_last ,max(D_61_last) - avg(D_61) as D_61_ldiff
,max(B_15_last) as B_15_last ,max(B_15_last) - avg(B_15) as B_15_ldiff
,max(S_11_last) as S_11_last ,max(S_11_last) - avg(S_11) as S_11_ldiff
,max(D_62_last) as D_62_last ,max(D_62_last) - avg(D_62) as D_62_ldiff
,max(D_63_last) as D_63_last
,max(D_64_last) as D_64_last
,max(D_65_last) as D_65_last ,max(D_65_last) - avg(D_65) as D_65_ldiff
,max(B_16_last) as B_16_last ,max(B_16_last) - avg(B_16) as B_16_ldiff
,max(B_17_last) as B_17_last ,max(B_17_last) - avg(B_17) as B_17_ldiff
,max(B_18_last) as B_18_last ,max(B_18_last) - avg(B_18) as B_18_ldiff
,max(B_19_last) as B_19_last ,max(B_19_last) - avg(B_19) as B_19_ldiff
,max(D_66_last) as D_66_last
,max(B_20_last) as B_20_last ,max(B_20_last) - avg(B_20) as B_20_ldiff
,max(D_68_last) as D_68_last
,max(S_12_last) as S_12_last ,max(S_12_last) - avg(S_12) as S_12_ldiff
,max(R_6_last) as R_6_last ,max(R_6_last) - avg(R_6) as R_6_ldiff
,max(S_13_last) as S_13_last ,max(S_13_last) - avg(S_13) as S_13_ldiff
,max(B_21_last) as B_21_last ,max(B_21_last) - avg(B_21) as B_21_ldiff
,max(D_69_last) as D_69_last ,max(D_69_last) - avg(D_69) as D_69_ldiff
,max(B_22_last) as B_22_last ,max(B_22_last) - avg(B_22) as B_22_ldiff
,max(D_70_last) as D_70_last ,max(D_70_last) - avg(D_70) as D_70_ldiff
,max(D_71_last) as D_71_last ,max(D_71_last) - avg(D_71) as D_71_ldiff
,max(D_72_last) as D_72_last ,max(D_72_last) - avg(D_72) as D_72_ldiff
,max(S_15_last) as S_15_last ,max(S_15_last) - avg(S_15) as S_15_ldiff
,max(B_23_last) as B_23_last ,max(B_23_last) - avg(B_23) as B_23_ldiff
,max(D_73_last) as D_73_last ,max(D_73_last) - avg(D_73) as D_73_ldiff
,max(P_4_last) as P_4_last ,max(P_4_last) - avg(P_4) as P_4_ldiff
,max(D_74_last) as D_74_last ,max(D_74_last) - avg(D_74) as D_74_ldiff
,max(D_75_last) as D_75_last ,max(D_75_last) - avg(D_75) as D_75_ldiff
,max(D_76_last) as D_76_last ,max(D_76_last) - avg(D_76) as D_76_ldiff
,max(B_24_last) as B_24_last ,max(B_24_last) - avg(B_24) as B_24_ldiff
,max(R_7_last) as R_7_last ,max(R_7_last) - avg(R_7) as R_7_ldiff
,max(D_77_last) as D_77_last ,max(D_77_last) - avg(D_77) as D_77_ldiff
,max(B_25_last) as B_25_last ,max(B_25_last) - avg(B_25) as B_25_ldiff
,max(B_26_last) as B_26_last ,max(B_26_last) - avg(B_26) as B_26_ldiff
,max(D_78_last) as D_78_last ,max(D_78_last) - avg(D_78) as D_78_ldiff
,max(D_79_last) as D_79_last ,max(D_79_last) - avg(D_79) as D_79_ldiff
,max(R_8_last) as R_8_last ,max(R_8_last) - avg(R_8) as R_8_ldiff
,max(R_9_last) as R_9_last ,max(R_9_last) - avg(R_9) as R_9_ldiff
,max(S_16_last) as S_16_last ,max(S_16_last) - avg(S_16) as S_16_ldiff
,max(D_80_last) as D_80_last ,max(D_80_last) - avg(D_80) as D_80_ldiff
,max(R_10_last) as R_10_last ,max(R_10_last) - avg(R_10) as R_10_ldiff
,max(R_11_last) as R_11_last ,max(R_11_last) - avg(R_11) as R_11_ldiff
,max(B_27_last) as B_27_last ,max(B_27_last) - avg(B_27) as B_27_ldiff
,max(D_81_last) as D_81_last ,max(D_81_last) - avg(D_81) as D_81_ldiff
,max(D_82_last) as D_82_last ,max(D_82_last) - avg(D_82) as D_82_ldiff
,max(S_17_last) as S_17_last ,max(S_17_last) - avg(S_17) as S_17_ldiff
,max(R_12_last) as R_12_last ,max(R_12_last) - avg(R_12) as R_12_ldiff
,max(B_28_last) as B_28_last ,max(B_28_last) - avg(B_28) as B_28_ldiff
,max(R_13_last) as R_13_last ,max(R_13_last) - avg(R_13) as R_13_ldiff
,max(D_83_last) as D_83_last ,max(D_83_last) - avg(D_83) as D_83_ldiff
,max(R_14_last) as R_14_last ,max(R_14_last) - avg(R_14) as R_14_ldiff
,max(R_15_last) as R_15_last ,max(R_15_last) - avg(R_15) as R_15_ldiff
,max(D_84_last) as D_84_last ,max(D_84_last) - avg(D_84) as D_84_ldiff
,max(R_16_last) as R_16_last ,max(R_16_last) - avg(R_16) as R_16_ldiff
,max(B_29_last) as B_29_last ,max(B_29_last) - avg(B_29) as B_29_ldiff
,max(B_30_last) as B_30_last
,max(S_18_last) as S_18_last ,max(S_18_last) - avg(S_18) as S_18_ldiff
,max(D_86_last) as D_86_last ,max(D_86_last) - avg(D_86) as D_86_ldiff
,max(D_87_last) as D_87_last ,max(D_87_last) - avg(D_87) as D_87_ldiff
,max(R_17_last) as R_17_last ,max(R_17_last) - avg(R_17) as R_17_ldiff
,max(R_18_last) as R_18_last ,max(R_18_last) - avg(R_18) as R_18_ldiff
,max(D_88_last) as D_88_last ,max(D_88_last) - avg(D_88) as D_88_ldiff
,max(B_31_last) as B_31_last ,max(B_31_last) - avg(B_31) as B_31_ldiff
,max(S_19_last) as S_19_last ,max(S_19_last) - avg(S_19) as S_19_ldiff
,max(R_19_last) as R_19_last ,max(R_19_last) - avg(R_19) as R_19_ldiff
,max(B_32_last) as B_32_last ,max(B_32_last) - avg(B_32) as B_32_ldiff
,max(S_20_last) as S_20_last ,max(S_20_last) - avg(S_20) as S_20_ldiff
,max(R_20_last) as R_20_last ,max(R_20_last) - avg(R_20) as R_20_ldiff
,max(R_21_last) as R_21_last ,max(R_21_last) - avg(R_21) as R_21_ldiff
,max(B_33_last) as B_33_last ,max(B_33_last) - avg(B_33) as B_33_ldiff
,max(D_89_last) as D_89_last ,max(D_89_last) - avg(D_89) as D_89_ldiff
,max(R_22_last) as R_22_last ,max(R_22_last) - avg(R_22) as R_22_ldiff
,max(R_23_last) as R_23_last ,max(R_23_last) - avg(R_23) as R_23_ldiff
,max(D_91_last) as D_91_last ,max(D_91_last) - avg(D_91) as D_91_ldiff
,max(D_92_last) as D_92_last ,max(D_92_last) - avg(D_92) as D_92_ldiff
,max(D_93_last) as D_93_last ,max(D_93_last) - avg(D_93) as D_93_ldiff
,max(D_94_last) as D_94_last ,max(D_94_last) - avg(D_94) as D_94_ldiff
,max(R_24_last) as R_24_last ,max(R_24_last) - avg(R_24) as R_24_ldiff
,max(R_25_last) as R_25_last ,max(R_25_last) - avg(R_25) as R_25_ldiff
,max(D_96_last) as D_96_last ,max(D_96_last) - avg(D_96) as D_96_ldiff
,max(S_22_last) as S_22_last ,max(S_22_last) - avg(S_22) as S_22_ldiff
,max(S_23_last) as S_23_last ,max(S_23_last) - avg(S_23) as S_23_ldiff
,max(S_24_last) as S_24_last ,max(S_24_last) - avg(S_24) as S_24_ldiff
,max(S_25_last) as S_25_last ,max(S_25_last) - avg(S_25) as S_25_ldiff
,max(S_26_last) as S_26_last ,max(S_26_last) - avg(S_26) as S_26_ldiff
,max(D_102_last) as D_102_last ,max(D_102_last) - avg(D_102) as D_102_ldiff
,max(D_103_last) as D_103_last ,max(D_103_last) - avg(D_103) as D_103_ldiff
,max(D_104_last) as D_104_last ,max(D_104_last) - avg(D_104) as D_104_ldiff
,max(D_105_last) as D_105_last ,max(D_105_last) - avg(D_105) as D_105_ldiff
,max(D_106_last) as D_106_last ,max(D_106_last) - avg(D_106) as D_106_ldiff
,max(D_107_last) as D_107_last ,max(D_107_last) - avg(D_107) as D_107_ldiff
,max(B_36_last) as B_36_last ,max(B_36_last) - avg(B_36) as B_36_ldiff
,max(B_37_last) as B_37_last ,max(B_37_last) - avg(B_37) as B_37_ldiff
,max(R_26_last) as R_26_last ,max(R_26_last) - avg(R_26) as R_26_ldiff
,max(R_27_last) as R_27_last ,max(R_27_last) - avg(R_27) as R_27_ldiff
,max(B_38_last) as B_38_last
,max(D_108_last) as D_108_last ,max(D_108_last) - avg(D_108) as D_108_ldiff
,max(D_109_last) as D_109_last ,max(D_109_last) - avg(D_109) as D_109_ldiff
,max(D_110_last) as D_110_last ,max(D_110_last) - avg(D_110) as D_110_ldiff
,max(D_111_last) as D_111_last ,max(D_111_last) - avg(D_111) as D_111_ldiff
,max(B_39_last) as B_39_last ,max(B_39_last) - avg(B_39) as B_39_ldiff
,max(D_112_last) as D_112_last ,max(D_112_last) - avg(D_112) as D_112_ldiff
,max(B_40_last) as B_40_last ,max(B_40_last) - avg(B_40) as B_40_ldiff
,max(S_27_last) as S_27_last ,max(S_27_last) - avg(S_27) as S_27_ldiff
,max(D_113_last) as D_113_last ,max(D_113_last) - avg(D_113) as D_113_ldiff
,max(D_114_last) as D_114_last
,max(D_115_last) as D_115_last ,max(D_115_last) - avg(D_115) as D_115_ldiff
,max(D_116_last) as D_116_last
,max(D_117_last) as D_117_last
,max(D_118_last) as D_118_last ,max(D_118_last) - avg(D_118) as D_118_ldiff
,max(D_119_last) as D_119_last ,max(D_119_last) - avg(D_119) as D_119_ldiff
,max(D_120_last) as D_120_last
,max(D_121_last) as D_121_last ,max(D_121_last) - avg(D_121) as D_121_ldiff
,max(D_122_last) as D_122_last ,max(D_122_last) - avg(D_122) as D_122_ldiff
,max(D_123_last) as D_123_last ,max(D_123_last) - avg(D_123) as D_123_ldiff
,max(D_124_last) as D_124_last ,max(D_124_last) - avg(D_124) as D_124_ldiff
,max(D_125_last) as D_125_last ,max(D_125_last) - avg(D_125) as D_125_ldiff
,max(D_126_last) as D_126_last
,max(D_127_last) as D_127_last ,max(D_127_last) - avg(D_127) as D_127_ldiff
,max(D_128_last) as D_128_last ,max(D_128_last) - avg(D_128) as D_128_ldiff
,max(D_129_last) as D_129_last ,max(D_129_last) - avg(D_129) as D_129_ldiff
,max(B_41_last) as B_41_last ,max(B_41_last) - avg(B_41) as B_41_ldiff
,max(B_42_last) as B_42_last ,max(B_42_last) - avg(B_42) as B_42_ldiff
,max(D_130_last) as D_130_last ,max(D_130_last) - avg(D_130) as D_130_ldiff
,max(D_131_last) as D_131_last ,max(D_131_last) - avg(D_131) as D_131_ldiff
,max(D_132_last) as D_132_last ,max(D_132_last) - avg(D_132) as D_132_ldiff
,max(D_133_last) as D_133_last ,max(D_133_last) - avg(D_133) as D_133_ldiff
,max(R_28_last) as R_28_last ,max(R_28_last) - avg(R_28) as R_28_ldiff
,max(D_134_last) as D_134_last ,max(D_134_last) - avg(D_134) as D_134_ldiff
,max(D_135_last) as D_135_last ,max(D_135_last) - avg(D_135) as D_135_ldiff
,max(D_136_last) as D_136_last ,max(D_136_last) - avg(D_136) as D_136_ldiff
,max(D_137_last) as D_137_last ,max(D_137_last) - avg(D_137) as D_137_ldiff
,max(D_138_last) as D_138_last ,max(D_138_last) - avg(D_138) as D_138_ldiff
,max(D_139_last) as D_139_last ,max(D_139_last) - avg(D_139) as D_139_ldiff
,max(D_140_last) as D_140_last ,max(D_140_last) - avg(D_140) as D_140_ldiff
,max(D_141_last) as D_141_last ,max(D_141_last) - avg(D_141) as D_141_ldiff
,max(D_142_last) as D_142_last ,max(D_142_last) - avg(D_142) as D_142_ldiff
,max(D_143_last) as D_143_last ,max(D_143_last) - avg(D_143) as D_143_ldiff
,max(D_144_last) as D_144_last ,max(D_144_last) - avg(D_144) as D_144_ldiff
,max(D_145_last) as D_145_last ,max(D_145_last) - avg(D_145) as  D_145_ldiff

from
(select *,
LAST_VALUE(P_2) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS P_2_last,
LAST_VALUE(D_39) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_39_last,
LAST_VALUE(B_1) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS B_1_last,
LAST_VALUE(B_2) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS B_2_last,
LAST_VALUE(R_1) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS R_1_last,
LAST_VALUE(S_3) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS S_3_last,
LAST_VALUE(D_41) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_41_last,
LAST_VALUE(B_3) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS B_3_last,
LAST_VALUE(D_42) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_42_last,
LAST_VALUE(D_43) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_43_last,
LAST_VALUE(D_44) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_44_last,
LAST_VALUE(B_4) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS B_4_last,
LAST_VALUE(D_45) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_45_last,
LAST_VALUE(B_5) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS B_5_last,
LAST_VALUE(R_2) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS R_2_last,
LAST_VALUE(D_46) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_46_last,
LAST_VALUE(D_47) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_47_last,
LAST_VALUE(D_48) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_48_last,
LAST_VALUE(D_49) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_49_last,
LAST_VALUE(B_6) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS B_6_last,
LAST_VALUE(B_7) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS B_7_last,
LAST_VALUE(B_8) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS B_8_last,
LAST_VALUE(D_50) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_50_last,
LAST_VALUE(D_51) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_51_last,
LAST_VALUE(B_9) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS B_9_last,
LAST_VALUE(R_3) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS R_3_last,
LAST_VALUE(D_52) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_52_last,
LAST_VALUE(P_3) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS P_3_last,
LAST_VALUE(B_10) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS B_10_last,
LAST_VALUE(D_53) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_53_last,
LAST_VALUE(S_5) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS S_5_last,
LAST_VALUE(B_11) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS B_11_last,
LAST_VALUE(S_6) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS S_6_last,
LAST_VALUE(D_54) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_54_last,
LAST_VALUE(R_4) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS R_4_last,
LAST_VALUE(S_7) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS S_7_last,
LAST_VALUE(B_12) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS B_12_last,
LAST_VALUE(S_8) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS S_8_last,
LAST_VALUE(D_55) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_55_last,
LAST_VALUE(D_56) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_56_last,
LAST_VALUE(B_13) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS B_13_last,
LAST_VALUE(R_5) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS R_5_last,
LAST_VALUE(D_58) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_58_last,
LAST_VALUE(S_9) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS S_9_last,
LAST_VALUE(B_14) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS B_14_last,
LAST_VALUE(D_59) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_59_last,
LAST_VALUE(D_60) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_60_last,
LAST_VALUE(D_61) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_61_last,
LAST_VALUE(B_15) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS B_15_last,
LAST_VALUE(S_11) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS S_11_last,
LAST_VALUE(D_62) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_62_last,
LAST_VALUE(D_63) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_63_last,
LAST_VALUE(D_64) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_64_last,
LAST_VALUE(D_65) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_65_last,
LAST_VALUE(B_16) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS B_16_last,
LAST_VALUE(B_17) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS B_17_last,
LAST_VALUE(B_18) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS B_18_last,
LAST_VALUE(B_19) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS B_19_last,
LAST_VALUE(D_66) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_66_last,
LAST_VALUE(B_20) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS B_20_last,
LAST_VALUE(D_68) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_68_last,
LAST_VALUE(S_12) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS S_12_last,
LAST_VALUE(R_6) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS R_6_last,
LAST_VALUE(S_13) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS S_13_last,
LAST_VALUE(B_21) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS B_21_last,
LAST_VALUE(D_69) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_69_last,
LAST_VALUE(B_22) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS B_22_last,
LAST_VALUE(D_70) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_70_last,
LAST_VALUE(D_71) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_71_last,
LAST_VALUE(D_72) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_72_last,
LAST_VALUE(S_15) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS S_15_last,
LAST_VALUE(B_23) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS B_23_last,
LAST_VALUE(D_73) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_73_last,
LAST_VALUE(P_4) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS P_4_last,
LAST_VALUE(D_74) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_74_last,
LAST_VALUE(D_75) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_75_last,
LAST_VALUE(D_76) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_76_last,
LAST_VALUE(B_24) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS B_24_last,
LAST_VALUE(R_7) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS R_7_last,
LAST_VALUE(D_77) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_77_last,
LAST_VALUE(B_25) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS B_25_last,
LAST_VALUE(B_26) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS B_26_last,
LAST_VALUE(D_78) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_78_last,
LAST_VALUE(D_79) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_79_last,
LAST_VALUE(R_8) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS R_8_last,
LAST_VALUE(R_9) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS R_9_last,
LAST_VALUE(S_16) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS S_16_last,
LAST_VALUE(D_80) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_80_last,
LAST_VALUE(R_10) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS R_10_last,
LAST_VALUE(R_11) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS R_11_last,
LAST_VALUE(B_27) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS B_27_last,
LAST_VALUE(D_81) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_81_last,
LAST_VALUE(D_82) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_82_last,
LAST_VALUE(S_17) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS S_17_last,
LAST_VALUE(R_12) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS R_12_last,
LAST_VALUE(B_28) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS B_28_last,
LAST_VALUE(R_13) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS R_13_last,
LAST_VALUE(D_83) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_83_last,
LAST_VALUE(R_14) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS R_14_last,
LAST_VALUE(R_15) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS R_15_last,
LAST_VALUE(D_84) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_84_last,
LAST_VALUE(R_16) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS R_16_last,
LAST_VALUE(B_29) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS B_29_last,
LAST_VALUE(B_30) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS B_30_last,
LAST_VALUE(S_18) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS S_18_last,
LAST_VALUE(D_86) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_86_last,
LAST_VALUE(D_87) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_87_last,
LAST_VALUE(R_17) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS R_17_last,
LAST_VALUE(R_18) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS R_18_last,
LAST_VALUE(D_88) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_88_last,
LAST_VALUE(B_31) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS B_31_last,
LAST_VALUE(S_19) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS S_19_last,
LAST_VALUE(R_19) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS R_19_last,
LAST_VALUE(B_32) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS B_32_last,
LAST_VALUE(S_20) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS S_20_last,
LAST_VALUE(R_20) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS R_20_last,
LAST_VALUE(R_21) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS R_21_last,
LAST_VALUE(B_33) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS B_33_last,
LAST_VALUE(D_89) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_89_last,
LAST_VALUE(R_22) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS R_22_last,
LAST_VALUE(R_23) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS R_23_last,
LAST_VALUE(D_91) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_91_last,
LAST_VALUE(D_92) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_92_last,
LAST_VALUE(D_93) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_93_last,
LAST_VALUE(D_94) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_94_last,
LAST_VALUE(R_24) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS R_24_last,
LAST_VALUE(R_25) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS R_25_last,
LAST_VALUE(D_96) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_96_last,
LAST_VALUE(S_22) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS S_22_last,
LAST_VALUE(S_23) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS S_23_last,
LAST_VALUE(S_24) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS S_24_last,
LAST_VALUE(S_25) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS S_25_last,
LAST_VALUE(S_26) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS S_26_last,
LAST_VALUE(D_102) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_102_last,
LAST_VALUE(D_103) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_103_last,
LAST_VALUE(D_104) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_104_last,
LAST_VALUE(D_105) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_105_last,
LAST_VALUE(D_106) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_106_last,
LAST_VALUE(D_107) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_107_last,
LAST_VALUE(B_36) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS B_36_last,
LAST_VALUE(B_37) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS B_37_last,
LAST_VALUE(R_26) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS R_26_last,
LAST_VALUE(R_27) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS R_27_last,
LAST_VALUE(B_38) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS B_38_last,
LAST_VALUE(D_108) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_108_last,
LAST_VALUE(D_109) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_109_last,
LAST_VALUE(D_110) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_110_last,
LAST_VALUE(D_111) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_111_last,
LAST_VALUE(B_39) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS B_39_last,
LAST_VALUE(D_112) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_112_last,
LAST_VALUE(B_40) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS B_40_last,
LAST_VALUE(S_27) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS S_27_last,
LAST_VALUE(D_113) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_113_last,
LAST_VALUE(D_114) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_114_last,
LAST_VALUE(D_115) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_115_last,
LAST_VALUE(D_116) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_116_last,
LAST_VALUE(D_117) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_117_last,
LAST_VALUE(D_118) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_118_last,
LAST_VALUE(D_119) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_119_last,
LAST_VALUE(D_120) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_120_last,
LAST_VALUE(D_121) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_121_last,
LAST_VALUE(D_122) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_122_last,
LAST_VALUE(D_123) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_123_last,
LAST_VALUE(D_124) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_124_last,
LAST_VALUE(D_125) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_125_last,
LAST_VALUE(D_126) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_126_last,
LAST_VALUE(D_127) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_127_last,
LAST_VALUE(D_128) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_128_last,
LAST_VALUE(D_129) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_129_last,
LAST_VALUE(B_41) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS B_41_last,
LAST_VALUE(B_42) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS B_42_last,
LAST_VALUE(D_130) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_130_last,
LAST_VALUE(D_131) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_131_last,
LAST_VALUE(D_132) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_132_last,
LAST_VALUE(D_133) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_133_last,
LAST_VALUE(R_28) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS R_28_last,
LAST_VALUE(D_134) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_134_last,
LAST_VALUE(D_135) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_135_last,
LAST_VALUE(D_136) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_136_last,
LAST_VALUE(D_137) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_137_last,
LAST_VALUE(D_138) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_138_last,
LAST_VALUE(D_139) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_139_last,
LAST_VALUE(D_140) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_140_last,
LAST_VALUE(D_141) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_141_last,
LAST_VALUE(D_142) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_142_last,
LAST_VALUE(D_143) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_143_last,
LAST_VALUE(D_144) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_144_last,
LAST_VALUE(D_145) OVER (PARTITION BY customer_ID ORDER BY customer_ID, S_2 ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS D_145_last

-- FROM `black-sanctum-358708.kaggle_amex.train_data`
FROM `black-sanctum-358708.kaggle_amex.test_data`
) as X
group by customer_ID

order by customer_ID

--  LIMIT 1000
