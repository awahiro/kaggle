# %%
# !pip install jupyter-resource-usage
# !pip install tables
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 KB 232.5 kB/s eta 0:00:001m292.1 kB/s eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 344.9/344.9 KB 1.2 MB/s eta 0:00:000:00:010:00:01:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.3/54.3 KB 1.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 KB 2.1 MB/s eta 0:00:00
# ...
#   Using cached sniffio-1.2.0-py3-none-any.whl (10 kB)
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.2.1 is available.
# You should consider upgrading via the '/Users/awashima/.pyenv/versions/3.10.4/bin/python3.10 -m pip install --upgrade pip' command.

# %%
# D_* = 債務不履行 変数
# S_* = 使途 変数
# P_* = 支払 変数
# B_* = 残高 変数
# R_* = リスク 変数

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import os
import pandas_profiling as pp

warnings.filterwarnings('ignore')
# %matplotlib inline

print(os.curdir)
print(os.listdir("input"))

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))

hdf = pd.HDFStore('./store.hdf5')

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
# Out:
# .
# ['train_labels.csv', 'test_data_100.csv', 'train_data_100000.csv', 'train_data_100.csv', 'train_data.csv', 'test_data_100000.csv', 'train_data_10000.csv', 'memo.txt', 'test_data_10000.csv', 'test_data.csv', 'sample_submission.csv']
# <style>.container { width:80% !important; }</style>

# %%
# %time test = pd.read_csv('input/test_data.csv')
# sample_submission = pd.read_csv('input/sample_submission.csv')

# %%
### train_labels.csv
# %time train_y = pd.read_csv('input/train_labels.csv')
# %time hdf.put(key='train_y', value=train_y)
# %time train_y = hdf.get(key='train_y')
# print(train_y)
# Out:
# CPU times: user 397 ms, sys: 64.9 ms, total: 462 ms
# Wall time: 459 ms
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File <timed eval>:1, in <module>
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/site-packages/pandas/io/pytables.py:1122, in HDFStore.put(self, key, value, format, index, append, complib, complevel, min_itemsize, nan_rep, data_columns, encoding, errors, track_times, dropna)
#    1120     format = get_option("io.hdf.default_format") or "fixed"
#    1121 format = self._validate_format(format)
# -> 1122 self._write_to_group(
#    1123     key,
#    1124     value,
#    1125     format=format,
#    1126     index=index,
#    1127     append=append,
#    1128     complib=complib,
#    1129     complevel=complevel,
#    1130     min_itemsize=min_itemsize,
#    1131     nan_rep=nan_rep,
#    1132     data_columns=data_columns,
#    1133     encoding=encoding,
# ...

# %%
### train_data.csv
# %time train = pd.read_csv('input/train_data.csv')
# %time hdf.put(key='train', value=train)
# %time train = hdf.get(key='train')

# %time train_100 = pd.read_csv('input/train_data_100.csv')
# %time hdf.put(key='train_100', value=train_100)
# %time train_100 = hdf.get(key='train_100')

# %time train_10k = pd.read_csv('input/train_data_10000.csv')
# %time hdf.put(key='train_10k', value=train_10k)
# %time train_10k = hdf.get(key='train_10k')

# %time train_100k = pd.read_csv('input/train_data_100000.csv')
# %time hdf.put(key='train_100k', value=train_100k)
# %time train_100k = hdf.get(key='train_100k')

### test_data.csv
# %time test = pd.read_csv('input/test_data.csv')
# %time hdf.put(key='test', value=test)
# %time test = hdf.get(key='test')

# %time test_100 = pd.read_csv('input/test_data_100.csv')
# %time hdf.put(key='test_100', value=test_100)
# %time test_100 = hdf.get(key='test_100')

# %time test_10k = pd.read_csv('input/test_data_10000.csv')
# %time hdf.put(key='test_10k', value=test_10k)
# %time test_10k = hdf.get(key='test_10k')

# %time test_100k = pd.read_csv('input/test_data_100000.csv')
# %time hdf.put(key='test_100k', value=test_100k)
# %time test_100k = hdf.get(key='test_100k')
# Out:
# CPU times: user 2min 40s, sys: 1min 41s, total: 4min 22s
# Wall time: 6min 25s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed eval>:1, in <module>
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/site-packages/pandas/io/pytables.py:1122, in HDFStore.put(self, key, value, format, index, append, complib, complevel, min_itemsize, nan_rep, data_columns, encoding, errors, track_times, dropna)
#    1120     format = get_option("io.hdf.default_format") or "fixed"
#    1121 format = self._validate_format(format)
# -> 1122 self._write_to_group(
#    1123     key,
#    1124     value,
#    1125     format=format,
#    1126     index=index,
#    1127     append=append,
#    1128     complib=complib,
#    1129     complevel=complevel,
#    1130     min_itemsize=min_itemsize,
#    1131     nan_rep=nan_rep,
#    1132     data_columns=data_columns,
# ...

# %%
# train_labelsのtargetの値（1or0）それぞれでサンプルデータとして10ずつcustomer_IDを抽出する
targets_0= []
targets_1= []
for row in train_y[train_y['target'] == 0][:10].iterrows():
    targets_0.append(row[1]['customer_ID'])
for row in train_y[train_y['target'] == 1][:10].iterrows():
    targets_1.append(row[1]['customer_ID'])
print(f"--- targets_0={targets_0}")
print(f"--- targets_1={targets_1}")
# サンプルデータのセットを保存する
s_train = train[train['customer_ID'].isin(targets_0) | train['customer_ID'].isin(targets_1)]
# %time hdf.put(key='s_train', value=s_train)
# %time s_train = hdf.get(key='s_train')

s_test = test[test['customer_ID'].isin(targets_0) | test['customer_ID'].isin(targets_1)]
# %time hdf.put(key='s_test', value=s_test)
# %time s_test = hdf.get(key='s_test')

# %%
# Out:
#                                            customer_ID         S_2       P_2  \
# 0    0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-03-09  0.938469
# 1    0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-04-07  0.936665
# 2    0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-05-28  0.954180
# 3    0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-06-13  0.960384
# 4    0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-07-16  0.947248
# 5    0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-08-04  0.945964
# 6    0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-09-18  0.940705
# 7    0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-10-08  0.914767
# 8    0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-11-20  0.950845
# 9    0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-12-04  0.868580
# 10   0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2018-01-11  0.909811
# ...

# %%
# %time s_merged = pd.merge(s_train, train_y, on='customer_ID', how='left')
s_merged
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [28], in <cell line: 1>()
# ----> 1 pd.merge(train, train_y, on='customer_ID', how='left')
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/site-packages/pandas/core/reshape/merge.py:122, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      90 @Substitution("\nleft : DataFrame or named Series")
#      91 @Appender(_merge_doc, indents=0)
#      92 def merge(
#    (...)
#     105     validate: str | None = None,
#     106 ) -> DataFrame:
#     107     op = _MergeOperation(
#     108         left,
#     109         right,
#    (...)
#     120         validate=validate,
#     121     )
# --> 122     return op.get_result()
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/site-packages/pandas/core/reshape/merge.py:725, in _MergeOperation.get_result(self)
# ...

# %%
from sklearn.model_selection import KFold, StratifiedKFold
import lightgbm as lgb


y_preds = []
models = []
oof_train = np.zeros((len(X_train),))
# cv = KFold(n_splits=5, shuffle=True, random_state=0)
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)
categorical_features = ['Embarked', 'Pclass', 'Sex']

params = {
    'objective': 'binary',
    'max_bin': 300,
    'learning_rate': 0.05,
    'num_leaves': 40
}

for fold_id, (train_index, valid_index) in enumerate(cv.split(X_train, y_train)):
    X_tr = X_train.loc[train_index, :]
    X_val = X_train.loc[valid_index, :]
    y_tr = y_train[train_index]
    y_val = y_train[valid_index]

    lgb_train = lgb.Dataset(X_tr, y_tr,
                                             categorical_feature=categorical_features)
    lgb_eval = lgb.Dataset(X_val, y_val, reference=lgb_train,
                                            categorical_feature=categorical_features)

    model = lgb.train(params, lgb_train,
                                   valid_sets=[lgb_train, lgb_eval],
                                   verbose_eval=10,
                                   num_boost_round=1000,
                                   early_stopping_rounds=10)


    oof_train[valid_index] = model.predict(X_val, num_iteration=model.best_iteration)
    y_pred = model.predict(X_test, num_iteration=model.best_iteration)

    y_preds.append(y_pred)
    models.append(model)

# %%
train[train['customer_ID'] == '0000099d6bd597052cdcda90ffabf56573fe9d7c79be5fbac11a8ed792feb62a']
# Out:
#                                           customer_ID         S_2       P_2  \
# 0   0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-03-09  0.938469
# 1   0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-04-07  0.936665
# 2   0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-05-28  0.954180
# 3   0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-06-13  0.960384
# 4   0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-07-16  0.947248
# 5   0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-08-04  0.945964
# 6   0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-09-18  0.940705
# 7   0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-10-08  0.914767
# 8   0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-11-20  0.950845
# 9   0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-12-04  0.868580
# 10  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2018-01-11  0.909811
# ...

# %%
t2 = train.dropna()

# %%
# D_* = 債務不履行 変数
# S_* = 使途 変数
# P_* = 支払 変数
# B_* = 残高 変数
# R_* = リスク 変数
train
# Out:
#                                                customer_ID         S_2  \
# 0        0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-03-09
# 1        0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-04-07
# 2        0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-05-28
# 3        0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-06-13
# 4        0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-07-16
# ...                                                    ...         ...
# 5531446  fffff1d38b785cef84adeace64f8f83db3a0c31e8d92ea...  2017-11-05
# 5531447  fffff1d38b785cef84adeace64f8f83db3a0c31e8d92ea...  2017-12-23
# 5531448  fffff1d38b785cef84adeace64f8f83db3a0c31e8d92ea...  2018-01-06
# 5531449  fffff1d38b785cef84adeace64f8f83db3a0c31e8d92ea...  2018-02-06
# 5531450  fffff1d38b785cef84adeace64f8f83db3a0c31e8d92ea...  2018-03-14
#
#               P_2      D_39       B_1       B_2       R_1       S_3      D_41  \
# ...

# %%
# %time hdf.get(key='train')
# Out:
# CPU times: user 9.55 ms, sys: 2.14 ms, total: 11.7 ms
# Wall time: 10.3 ms
#                                           customer_ID         S_2       P_2  \
# 0   0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-03-09  0.938469
# 1   0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-04-07  0.936665
# 2   0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-05-28  0.954180
# 3   0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-06-13  0.960384
# 4   0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-07-16  0.947248
# ..                                                ...         ...       ...
# 94  0000d17a1447b25a01e42e1ac56b091bb7cbb06317be4c...  2017-06-02  1.009520
# 95  0000d17a1447b25a01e42e1ac56b091bb7cbb06317be4c...  2017-07-23  1.009547
# 96  0000d17a1447b25a01e42e1ac56b091bb7cbb06317be4c...  2017-08-26  1.002364
# 97  0000d17a1447b25a01e42e1ac56b091bb7cbb06317be4c...  2017-09-26  1.000488
# ...

# %%
# train.sort_index(axis=1)
# train['D_129'].value_counts()

# %time train.shape
# Out:
# CPU times: user 19 µs, sys: 1e+03 ns, total: 20 µs
# Wall time: 24.1 µs
# (5531451, 190)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5531451 entries, 0 to 5531450
# Columns: 190 entries, customer_ID to D_145
# dtypes: float64(185), int64(1), object(4)
# memory usage: 7.8+ GB

# %%
# train.columns.str.startswith('D')
# train[train['P_2'] > 0]
print(train['D_63'].value_counts())
print(train['D_64'].value_counts())
# Out:
# CO    4119621
# CR     930133
# CL     438390
# XZ      25786
# XM      10556
# XL       6965
# Name: D_63, dtype: int64
# O     2913244
# U     1523448
# R      840112
# -1      37205
# Name: D_64, dtype: int64

# %%
test.head(5)
# Out:
#                                          customer_ID         S_2       P_2  \
# 0  00000469ba478561f23a92a868bd366de6f6527a684c9a...  2019-02-19  0.631315
# 1  00000469ba478561f23a92a868bd366de6f6527a684c9a...  2019-03-25  0.587042
# 2  00000469ba478561f23a92a868bd366de6f6527a684c9a...  2019-04-25  0.609056
# 3  00000469ba478561f23a92a868bd366de6f6527a684c9a...  2019-05-20  0.614911
# 4  00000469ba478561f23a92a868bd366de6f6527a684c9a...  2019-06-15  0.591673
#
#        D_39       B_1       B_2       R_1       S_3      D_41       B_3  \
# 0  0.001912  0.010728  0.814497  0.007547  0.168651  0.009971  0.002347
# 1  0.005275  0.011026  0.810848  0.001817  0.241389  0.000166  0.009132
# 2  0.003326  0.016390  1.004620  0.000114  0.266976  0.004196  0.004192
# 3  0.009065  0.021672  0.816549  0.009722  0.188947  0.004123  0.015325
# 4  0.238794  0.015923  0.810456  0.002026  0.180035  0.000731  0.011281
#
#        D_42  D_43      D_44       B_4      D_45       B_5       R_2      D_46  \
# ...

# %%
train.describe()
# Out:
#              P_2       D_39        B_1        B_2        R_1        S_3  \
# count  99.000000  99.000000  99.000000  99.000000  99.000000  77.000000
# mean    0.795741   0.097329   0.031284   0.779400   0.005315   0.212414
# std     0.179514   0.175990   0.041118   0.320272   0.002899   0.117351
# min     0.328983   0.000030   0.000776   0.040892   0.000030   0.073078
# 25%     0.623074   0.002469   0.007321   0.811878   0.002982   0.117325
# 50%     0.872014   0.006877   0.014589   0.819947   0.005684   0.162771
# 75%     0.920908   0.078871   0.037915   1.004902   0.007576   0.315459
# max     1.009547   0.711983   0.279991   1.009999   0.009960   0.463104
#
#             D_41        B_3       D_42       D_43       D_44        B_4  \
# count  99.000000  99.000000  11.000000  66.000000  86.000000  99.000000
# mean    0.005211   0.028781   0.142407   0.056043   0.006029   0.044806
# std     0.002830   0.052422   0.009691   0.068954   0.013604   0.064642
# ...
